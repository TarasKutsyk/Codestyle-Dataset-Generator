# %%
import pandas as pd
import csv

# %%
result_fname = 'result.csv'

# %%
df = pd.read_csv(result_fname)
df
# Out:
#                style_id                                               code  \
# 0  -5350093384733551968  bar = another_long_function(arg_one, arg_two,\...
# 1  -5350093384733551968  baz = yet_another_function(param1, param2,\n  ...
# 2  -5350093384733551968  qux = some_other_function(first_arg, second_ar...
# 3  -5350093384733551968  quux = a_different_function(argument1, argumen...
# 4  -5350093384733551968  corge = function_with_args(arg_a, arg_b,\n    ...
# ..                  ...                                                ...
# 65  4378129113783147367  filtered_data = filter_data(\n    'item1', 'it...
# 66  4378129113783147367  processed_result = process_result(\n    'value...
# 67  4378129113783147367  output_data = generate_output(\n    'input_a',...
# 68  4378129113783147367  final_result = compute_final_result(\n    'arg...
# 69  4378129113783147367  processed_output = process_output(\n    'data_...
#
#       label  processed
# 0   correct       True
# ...

# %%
df = df[df['processed'] == True]
df
# Out:
#                style_id                                               code  \
# 0  -5350093384733551968  bar = another_long_function(arg_one, arg_two,\...
# 1  -5350093384733551968  baz = yet_another_function(param1, param2,\n  ...
# 2  -5350093384733551968  qux = some_other_function(first_arg, second_ar...
# 3  -5350093384733551968  quux = a_different_function(argument1, argumen...
# 4  -5350093384733551968  corge = function_with_args(arg_a, arg_b,\n    ...
# ..                  ...                                                ...
# 65  4378129113783147367  filtered_data = filter_data(\n    'item1', 'it...
# 66  4378129113783147367  processed_result = process_result(\n    'value...
# 67  4378129113783147367  output_data = generate_output(\n    'input_a',...
# 68  4378129113783147367  final_result = compute_final_result(\n    'arg...
# 69  4378129113783147367  processed_output = process_output(\n    'data_...
#
#       label  processed
# 0   correct       True
# ...

# %%
df = df.set_index('style_id')
df
# Out:
#                                                                    code  \
# style_id
# -5350093384733551968  bar = another_long_function(arg_one, arg_two,\...
# -5350093384733551968  baz = yet_another_function(param1, param2,\n  ...
# -5350093384733551968  qux = some_other_function(first_arg, second_ar...
# -5350093384733551968  quux = a_different_function(argument1, argumen...
# -5350093384733551968  corge = function_with_args(arg_a, arg_b,\n    ...
# ...                                                                 ...
#  4378129113783147367  filtered_data = filter_data(\n    'item1', 'it...
#  4378129113783147367  processed_result = process_result(\n    'value...
#  4378129113783147367  output_data = generate_output(\n    'input_a',...
#  4378129113783147367  final_result = compute_final_result(\n    'arg...
#  4378129113783147367  processed_output = process_output(\n    'data_...
#
#                         label  processed
# style_id
# ...

# %%
df.to_csv(result_fname, mode='w', index=True, quoting=csv.QUOTE_ALL)
