# %%
import pandas as pd
import re
import json
import csv

from gpt_prompt import GPTClient

# %%
# CSV output file path
output_fname = 'result_gpt.csv'
fname_wrong  = 'dataset_wrong.csv'
fname_correct  = 'dataset_correct.csv'

df_wrong = pd.read_csv(fname_wrong, index_col='style')
df_correct = pd.read_csv(fname_correct, index_col='style')

df_wrong
# Out:
#                                                                                                  code  \
# style
# Aligned with opening delimiter.                     foo = long_function_name(var_one, var_two,\r\n...
# Add 4 spaces (an extra level of indentation) to...  def long_function_name(\r\n        var_one, va...
# Hanging indents should add a level.                 foo = long_function_name(\r\nvar_one, var_two,...
# No extra indentation (same level of indent).        if (this_is_one_thing and\r\n that_is_another_...
# Add some extra indentation on the conditional c...  if (this_is_one_thing\r\n     and that_is_anot...
# The closing brace/bracket/parenthesis on multil...     my_list = [\r\n    1, 2, 3,\r\n  4, 5, 6,\r\n]
# The closing brace/bracket/parenthesis on multil...  result = some_function_that_takes_arguments(\r...
#
#                                                     label  processed
# style
# Aligned with opening delimiter.                     wrong       True
# Add 4 spaces (an extra level of indentation) to...  wrong       True
# Hanging indents should add a level.                 wrong       True
# No extra indentation (same level of indent).        wrong       True
# Add some extra indentation on the conditional c...  wrong       True
# The closing brace/bracket/parenthesis on multil...  wrong       True
# The closing brace/bracket/parenthesis on multil...  wrong       True

# %%
# Discard all the processed examples
unprocessed_df = df_wrong[~df_wrong['processed']]
unprocessed_df
# Out:
# Empty DataFrame
# Columns: [code, label, processed]
# Index: []

# %%
df = unprocessed_df.join(df_correct, how='left', rsuffix='_correct')
df = df[['code', 'code_correct', 'aspects', 'label', 'processed']]

N_items = len(df.index)
N_before_join = len(unprocessed_df.index)

if N_before_join - N_items != 0:
    print(f'Warning: {N_before_join - N_items} items discarded because they didn\'t have corresponding correct snippets.')

df
# Out:
# Empty DataFrame
# Columns: [code, code_correct, aspects, label, processed]
# Index: []

# %%
def get_gpt_snippets(style, sample, verbose=False, **kwargs):
    """
    Prompt GPT and get its generated snippets based on the example from the sample row in the dataset.csv dataframe
    """
    # Parse the aspects as the list of abbreviations that generate_correct_samples() function expects
    aspects = sample.aspects.split('/')
    
    response = generate_wrong_samples(prompt_rule=style, aspects_list=aspects, wrong_code=sample.code, 
                                      correct_code=sample.code_correct, verbose=verbose, **kwargs)
    response_text = response.choices[0].message.content

    if verbose:
        print('RESPONSE:\n' + response_text)
    
    # Extract the generated snippets from the Claude's response
    result_section = re.search(r'<result>(.*)</result>', response_text, re.DOTALL).group(1)
    # Split the result section into individual code snippets
    code_snippets = result_section.strip().split('--\n')

    return code_snippets

def save_snippets(style, snippets, label, processed):
    with open(output_fname, 'a', newline='') as csvfile:
        csv_writer = csv.writer(csvfile, quoting=csv.QUOTE_ALL)

        for snippet in snippets:
            csv_writer.writerow([style, snippet, label, processed])

# %%
MODEL='gpt-4-turbo-2024-04-09'
TEMPERATURE=1
VERBOSE=True

# %%
for i, (style, sample) in enumerate(df.iterrows()):
    print(f'Sample #{i+1}: {style}', end='\n' * 2)
    
    code_snippets = get_gpt_snippets(style, sample, verbose=True, model=MODEL, temperature=TEMPERATURE)
    
    # Ask the user whether the generated snippets are satisfactory
    for snippet in code_snippets:
        print(snippet.strip())
        print('-' * 20) # for better readability

    print("Mark the sample as processed? y/n: ")
    processed_input  = input().lower()
    processed_answer = processed_input == 'y'

    df_wrong.loc[style, 'processed'] = processed_answer
    save_snippets(style, code_snippets, sample.label, processed_answer)
# Out:
# Sample #1: Aligned with opening delimiter.
#
# PROMPT:
#
# You are an expert programmer with extensive experience and vast knowledge of different industries. You will help me create a dataset for correcting a code style according to the PEP 8 Python guideline.
#
# You will be given an example of a stylistically *wrong* snippet, and your task is to generate a total of 10 similar snippets. When generating snippets, you must strictly adhere to the following instructions:
#
# <instructions>
# 1. Snippets are valid pieces of Python code that must be similar to the provided <wrong_snippet> example in a sense that they *must violate* a certain <style_rule> (all relevant data are provided to you below in the corresponding XML sections).
# 2. When generating similar wrong snippets, you may and should change the <wrong_snippet> example in all possible ways, except for one rule:
# 3. Snippets must not be identical to the <correct_snippet> in the <style_rule>
# 4. Since you will generate snippets for a ML dataset, they must have some variability, being different both from the provided examples and from each other. To provide this variability, you need to modify the provided examples in the aspects from the <other_aspects> data section. If some aspects from <other_aspects> are irrelevant to the provided examples, you can safely ignore them, and focus on relevant ones instead.
# 5. Pay special attention to identation: some <style_rule>s rely on a specific, fixed number of spaces in each new line of code (starting from '\n' symbol), so pay close attention *not* to keep the identation identical to the one provided in the <correct_snippet> example.
# </instructions>
#
# <style_rule>
# Aligned with opening delimiter.
# </style_rule>
#
# <correct_snippet>
# foo = long_function_name(var_one, var_two,
#                          var_three, var_four)
# </correct_snippet>
#
# <wrong_snippet>
# foo = long_function_name(var_one, var_two,
#                         var_three, var_four)
# </wrong_snippet>
#
# <other_aspects>
# - variable naming
# - function naming
# - number of function arguments
# - names of function arguments
# - length of function arguments (all arguments must be of different length)
#
# </other_aspects>
#
# <output_instruction>
# 1. By comparing the <correct_snippet> and <wrong_snippet>, start your output with defining all possible ways in which you can violate the <style rule>. Use all your experience of code reviewing to list out all the cases, in which inexperienced programmers could violate the rule, and enclose these cases into the <violate_instructions> tags.
# 2. Paying close attention in order *not* to generate the correct sample as in in the <correct_snippet> example, and using <violate_instructions> you just wrote, start generating stylistically wrong snippets that violate the <style_rule>. Each case from the <violate_instructions> should be covered by at least one generated snipper.
# 3. Generated snippets should be in the following format:
#     <result>
#     {code_snippet_1}
#     --
#     {code_snippet_2}
#     --
#     ...
#     --
#     {code_snippet_10}
#     </result>
# </output_instruction>
#
# RESPONSE:
# <violate_instructions>
# 1. Misalign the arguments by having an inconsistent indentation with the opening delimiter. This could include having too few or too many spaces resulting in the arguments not visually lining up nicely.
# 2. Change where the arguments begin on the line, impacting readability and alignment. The first argument on a new line can start at a different position instead of directly under the first argument after the opening parenthesis.
# 3. Only have one argument misaligned compared to others, which can especially happen if argument names are very variable in length.
# 4. Align the continuation lines improperly against unrelated syntax elements instead of aligning with the first argument after the function name.
# 5. Use different styles of alignment inconsistently across multiple lines, perhaps alternating leading spaces.
# 6. Place the second line of arguments at the beginning of the line, ignoring the need for continuation indentation entirely.
# 7. Indent the continuation line with tabs instead of spaces, which might not visually misalign in some editors but would be inconsistent in others due to the difference in tab display settings.
# 8. Use excessive indentation for the continuation lines making the code look disproportionately stretched horizontally.
# 9. Place multiple arguments on the continuation line after misaligning the first one, forcing all subsequent ones to also misalign.
# 10. Have no indentation for continuation lines, creating a style similar to the arguments being on the same line.
# </violate_instructions>
#
# <result>
# foo = calculate_summary(data_input, param_first,
# param_second, long_parameter)
# --
# calculate = massive_function(compute_base, extended_arg,
# height_param, very_big_argument)
# --
# result = process_entries(entry_one, data_second,
#     data_third, another_arg)
# --
# value = integrate_values(variable_x, short_var,
#                          midpoint, border_case_var)
# --
# response = send_request(request_data, metadata,
#                   details, extended_info)
# --
# example = run_simulation(sim_variable, environment_set,
#        config_details, parameters_lengthy)
# --
# compute = evaluate_metrics(metric_input, baseline_value,
#             custom_setting, additional_adjustment)
# --
# analysis = create_report(report_item, source_identifier,
#                  user_details, context_informations)
# --
# view = render_template(template_name, context_object,
# context_detail, long_context_information)
# --
# fetch = get_records(primary_key, record_field,
#                   secondary_field, optional_field_long)
# </result>
# foo = calculate_summary(data_input, param_first,
# param_second, long_parameter)
# --------------------
# calculate = massive_function(compute_base, extended_arg,
# height_param, very_big_argument)
# --------------------
# result = process_entries(entry_one, data_second,
#     data_third, another_arg)
# --------------------
# value = integrate_values(variable_x, short_var,
#                          midpoint, border_case_var)
# --------------------
# response = send_request(request_data, metadata,
#                   details, extended_info)
# --------------------
# example = run_simulation(sim_variable, environment_set,
#        config_details, parameters_lengthy)
# --------------------
# compute = evaluate_metrics(metric_input, baseline_value,
#             custom_setting, additional_adjustment)
# --------------------
# analysis = create_report(report_item, source_identifier,
#                  user_details, context_informations)
# --------------------
# view = render_template(template_name, context_object,
# context_detail, long_context_information)
# --------------------
# fetch = get_records(primary_key, record_field,
#                   secondary_field, optional_field_long)
# --------------------
# Mark the sample as processed? y/n:
#  n
# Sample #2: Add 4 spaces (an extra level of indentation) to distinguish arguments from the rest.
#
# PROMPT:
#
# You are an expert programmer with extensive experience and vast knowledge of different industries. You will help me create a dataset for correcting a code style according to the PEP 8 Python guideline.
#
# You will be given an example of a stylistically *wrong* snippet, and your task is to generate a total of 10 similar snippets. When generating snippets, you must strictly adhere to the following instructions:
#
# <instructions>
# 1. Snippets are valid pieces of Python code that must be similar to the provided <wrong_snippet> example in a sense that they *must violate* a certain <style_rule> (all relevant data are provided to you below in the corresponding XML sections).
# 2. When generating similar wrong snippets, you may and should change the <wrong_snippet> example in all possible ways, except for one rule:
# 3. Snippets must not be identical to the <correct_snippet> in the <style_rule>
# 4. Since you will generate snippets for a ML dataset, they must have some variability, being different both from the provided examples and from each other. To provide this variability, you need to modify the provided examples in the aspects from the <other_aspects> data section. If some aspects from <other_aspects> are irrelevant to the provided examples, you can safely ignore them, and focus on relevant ones instead.
# 5. Pay special attention to identation: some <style_rule>s rely on a specific, fixed number of spaces in each new line of code (starting from '\n' symbol), so pay close attention *not* to keep the identation identical to the one provided in the <correct_snippet> example.
# </instructions>
#
# <style_rule>
# Add 4 spaces (an extra level of indentation) to distinguish arguments from the rest.
# </style_rule>
#
# <correct_snippet>
# def long_function_name(
#         var_one, var_two, var_three,
#         var_four):
# </correct_snippet>
#
# <wrong_snippet>
# def long_function_name(
#         var_one, var_two, var_three,
#          var_four):
# </wrong_snippet>
#
# <other_aspects>
# - variable naming
# - function naming
# - number of function arguments
# - names of function arguments
# - length of function arguments (all arguments must be of different length)
#
# </other_aspects>
#
# <output_instruction>
# 1. By comparing the <correct_snippet> and <wrong_snippet>, start your output with defining all possible ways in which you can violate the <style rule>. Use all your experience of code reviewing to list out all the cases, in which inexperienced programmers could violate the rule, and enclose these cases into the <violate_instructions> tags.
# 2. Paying close attention in order *not* to generate the correct sample as in in the <correct_snippet> example, and using <violate_instructions> you just wrote, start generating stylistically wrong snippets that violate the <style_rule>. Each case from the <violate_instructions> should be covered by at least one generated snipper.
# 3. Generated snippets should be in the following format:
#     <result>
#     {code_snippet_1}
#     --
#     {code_snippet_2}
#     --
#     ...
#     --
#     {code_snippet_10}
#     </result>
# </output_instruction>
#
# RESPONSE:
# <violate_instructions>
# - Use 5 or more spaces for one or more of the arguments to incorrectly indent them, creating inconsistent alignment with other arguments.
# - Use 3 or fewer spaces in some lines to incorrectly reduce indentation below the required level.
# - Mix correct and incorrect indentation levels among the arguments to create an inconsistent appearance.
# - Vary indentation inconsistently across different uses of the same function definition or similar function definitions.
# </violate_instructions>
#
# <result>
# def process_data(
#         input_data, output_data,
#             processed_data, result_data):
# --
# def calculate_values(
#        value1, value2,
#            value3, long_value4):
# --
# def create_user_profile(
#          firstname, lastname,
#         username, password, email):
# --
# def connect_database(
#         host, port,
#      dbname, user, password):
# --
# def draw_shape(
#         center_point, edge_length,
#             number_of_sides, color):
# --
# def send_email(
#          recipient, sender,
#         subject, body, cc, bcc):
# --
# def start_engine(
#          model, make,
#            year, horsepower):
# --
# def mix_ingredients(
#         dry, wet,
#             flavoring, toppings):
# --
# def upload_document(
#         file_path,
#             metadata, destination_folder):
# --
# def add_numbers(
#         num1, num2,
#     num3, very_long_number_name):
# </result>
# def process_data(
#         input_data, output_data,
#             processed_data, result_data):
# --------------------
# def calculate_values(
#        value1, value2,
#            value3, long_value4):
# --------------------
# def create_user_profile(
#          firstname, lastname,
#         username, password, email):
# --------------------
# def connect_database(
#         host, port,
#      dbname, user, password):
# --------------------
# def draw_shape(
#         center_point, edge_length,
#             number_of_sides, color):
# --------------------
# def send_email(
#          recipient, sender,
#         subject, body, cc, bcc):
# --------------------
# def start_engine(
#          model, make,
#            year, horsepower):
# --------------------
# def mix_ingredients(
#         dry, wet,
#             flavoring, toppings):
# --------------------
# def upload_document(
#         file_path,
#             metadata, destination_folder):
# --------------------
# def add_numbers(
#         num1, num2,
#     num3, very_long_number_name):
# --------------------
# Mark the sample as processed? y/n:
#  y
# Sample #3: Hanging indents should add a level.
#
# PROMPT:
#
# You are an expert programmer with extensive experience and vast knowledge of different industries. You will help me create a dataset for correcting a code style according to the PEP 8 Python guideline.
#
# You will be given an example of a stylistically *wrong* snippet, and your task is to generate a total of 10 similar snippets. When generating snippets, you must strictly adhere to the following instructions:
#
# <instructions>
# 1. Snippets are valid pieces of Python code that must be similar to the provided <wrong_snippet> example in a sense that they *must violate* a certain <style_rule> (all relevant data are provided to you below in the corresponding XML sections).
# 2. When generating similar wrong snippets, you may and should change the <wrong_snippet> example in all possible ways, except for one rule:
# 3. Snippets must not be identical to the <correct_snippet> in the <style_rule>
# 4. Since you will generate snippets for a ML dataset, they must have some variability, being different both from the provided examples and from each other. To provide this variability, you need to modify the provided examples in the aspects from the <other_aspects> data section. If some aspects from <other_aspects> are irrelevant to the provided examples, you can safely ignore them, and focus on relevant ones instead.
# 5. Pay special attention to identation: some <style_rule>s rely on a specific, fixed number of spaces in each new line of code (starting from '\n' symbol), so pay close attention *not* to keep the identation identical to the one provided in the <correct_snippet> example.
# </instructions>
#
# <style_rule>
# Hanging indents should add a level.
# </style_rule>
#
# <correct_snippet>
# foo = long_function_name(
#     var_one, var_two,
#     var_three, var_four)
# </correct_snippet>
#
# <wrong_snippet>
# foo = long_function_name(
# var_one, var_two,
# var_three, var_four)
# </wrong_snippet>
#
# <other_aspects>
# - variable naming
# - function naming
# - number of function arguments
# - names of function arguments
# - length of function arguments (all arguments must be of different length)
#
# </other_aspects>
#
# <output_instruction>
# 1. By comparing the <correct_snippet> and <wrong_snippet>, start your output with defining all possible ways in which you can violate the <style rule>. Use all your experience of code reviewing to list out all the cases, in which inexperienced programmers could violate the rule, and enclose these cases into the <violate_instructions> tags.
# 2. Paying close attention in order *not* to generate the correct sample as in in the <correct_snippet> example, and using <violate_instructions> you just wrote, start generating stylistically wrong snippets that violate the <style_rule>. Each case from the <violate_instructions> should be covered by at least one generated snipper.
# 3. Generated snippets should be in the following format:
#     <result>
#     {code_snippet_1}
#     --
#     {code_snippet_2}
#     --
#     ...
#     --
#     {code_snippet_10}
#     </result>
# </output_instruction>
#
# RESPONSE:
# <violate_instructions>
# 1. Avoid adding any indentation after the opening parenthesis for the wrapped lines.
# 2. Add inconsistent indentation among the arguments spread over multiple lines.
# 3. Place all function arguments on new lines without any indentation.
# 4. Use less indent than recommended on subsequent lines, like one space or two instead of four.
# 5. Use excessive indentation for each argument line, such as six or more spaces.
# 6. Indent only some of the lines with arguments, leaving at least one line unindented or less indented.
# 7. Add random or varying amounts of indentations on different lines for arguments.
# 8. All arguments in a single line after the function name but wrapped incorrectly without indentation.
# 9. Use indentation that shifts leftward or rightward progressively on every new line.
# 10. Mix tabs and spaces in the indentation for greater inconsistency.
# </violate_instructions>
#
# <result>
# resultA = calculate_maximum_result(
# valueX, valueY,
# valueZ, anOptionalFlag)
# --
# compute_values = parse_data_through_network(
#    dataInput, networkStatus,
# outputLocation, lastAccessTime)
# --
# minimum_find = get_minimum_value(
# aParameter, bParameter, cParameter,
# dParameter)
# --
# analyze_data = start_data_analysis(
#             inputSet1, inputSet2,
#             controlValue, experimentValue)
# --
# match_patterns = pattern_recognition_algorithm(
#     pattern1, pattern2, pattern3,
# pattern4)
# --
# extract_features = feature_extraction_method(
# testInput, processStatus,
#           resultOutput, flagsUsed)
# --
# launch_simulation = init_simulation_config(
#    configParam, simDetail, ongoingStatus, finalResult)
# --
# calculate_statistics = generate_stats(
#     stat_input_one, stat_input_two,
#     stat_input_three, finalStat)
# --
# init_process = load_process_env(
#        environmentVars, userConfigs,
# systemSettings, loadBalancer)
# --
# merge_datasets = combine_datasets_function(
#     datasetOne, datasetTwo,
#               metadataInfo, mergeOptions)
# --
# </result>
# resultA = calculate_maximum_result(
# valueX, valueY,
# valueZ, anOptionalFlag)
# --------------------
# compute_values = parse_data_through_network(
#    dataInput, networkStatus,
# outputLocation, lastAccessTime)
# --------------------
# minimum_find = get_minimum_value(
# aParameter, bParameter, cParameter,
# dParameter)
# --------------------
# analyze_data = start_data_analysis(
#             inputSet1, inputSet2,
#             controlValue, experimentValue)
# --------------------
# match_patterns = pattern_recognition_algorithm(
#     pattern1, pattern2, pattern3,
# pattern4)
# --------------------
# extract_features = feature_extraction_method(
# testInput, processStatus,
#           resultOutput, flagsUsed)
# --------------------
# launch_simulation = init_simulation_config(
#    configParam, simDetail, ongoingStatus, finalResult)
# --------------------
# calculate_statistics = generate_stats(
#     stat_input_one, stat_input_two,
#     stat_input_three, finalStat)
# --------------------
# init_process = load_process_env(
#        environmentVars, userConfigs,
# systemSettings, loadBalancer)
# --------------------
# merge_datasets = combine_datasets_function(
#     datasetOne, datasetTwo,
#               metadataInfo, mergeOptions)
# --
# --------------------
# Mark the sample as processed? y/n:
#  n
# Sample #4: No extra indentation (same level of indent).
#
# PROMPT:
#
# You are an expert programmer with extensive experience and vast knowledge of different industries. You will help me create a dataset for correcting a code style according to the PEP 8 Python guideline.
#
# You will be given an example of a stylistically *wrong* snippet, and your task is to generate a total of 10 similar snippets. When generating snippets, you must strictly adhere to the following instructions:
#
# <instructions>
# 1. Snippets are valid pieces of Python code that must be similar to the provided <wrong_snippet> example in a sense that they *must violate* a certain <style_rule> (all relevant data are provided to you below in the corresponding XML sections).
# 2. When generating similar wrong snippets, you may and should change the <wrong_snippet> example in all possible ways, except for one rule:
# 3. Snippets must not be identical to the <correct_snippet> in the <style_rule>
# 4. Since you will generate snippets for a ML dataset, they must have some variability, being different both from the provided examples and from each other. To provide this variability, you need to modify the provided examples in the aspects from the <other_aspects> data section. If some aspects from <other_aspects> are irrelevant to the provided examples, you can safely ignore them, and focus on relevant ones instead.
# 5. Pay special attention to identation: some <style_rule>s rely on a specific, fixed number of spaces in each new line of code (starting from '\n' symbol), so pay close attention *not* to keep the identation identical to the one provided in the <correct_snippet> example.
# </instructions>
#
# <style_rule>
# No extra indentation (same level of indent).
# </style_rule>
#
# <correct_snippet>
# if (this_is_one_thing and
#     that_is_another_thing):
# </correct_snippet>
#
# <wrong_snippet>
# if (this_is_one_thing and
#  that_is_another_thing):
# </wrong_snippet>
#
# <other_aspects>
# - variable naming
# - function naming
#
# </other_aspects>
#
# <output_instruction>
# 1. By comparing the <correct_snippet> and <wrong_snippet>, start your output with defining all possible ways in which you can violate the <style rule>. Use all your experience of code reviewing to list out all the cases, in which inexperienced programmers could violate the rule, and enclose these cases into the <violate_instructions> tags.
# 2. Paying close attention in order *not* to generate the correct sample as in in the <correct_snippet> example, and using <violate_instructions> you just wrote, start generating stylistically wrong snippets that violate the <style_rule>. Each case from the <violate_instructions> should be covered by at least one generated snipper.
# 3. Generated snippets should be in the following format:
#     <result>
#     {code_snippet_1}
#     --
#     {code_snippet_2}
#     --
#     ...
#     --
#     {code_snippet_10}
#     </result>
# </output_instruction>
#
# RESPONSE:
# <violate_instructions>
# - Use fewer indentation spaces than in the correct snippet for continuation lines.
# - Use more indentation spaces than necessary for continuation lines.
# - Mix tabs and spaces inconsistently in the indentation.
# </violate_instructions>
#
# <result>
# if (check_one_condition and
#  check_other_condition):
# #
# --
# if (is_valid_entry and
#    is_not_duplicate_entry):
# --
# if (user_active and
# user_has_permissions):
# --
# if (validate_input(data) and
#      ensure_data_security(data)):
# --
# if (data_is_ready and
# 		process_data_now()):
# --
# if (can_proceed() and
#      is_safe_operation()):
# --
# if (model_is_trained and
# 			  generate_predictions()):
# --
# if (send_data_available and
# 	send_data()):
# --
# if (data_clean and
# 		        pass_checks()):
# --
# if (user_authenticated and
# 			user_not_restricted()):
# </result>
# if (check_one_condition and
#  check_other_condition):
# #
# --------------------
# if (is_valid_entry and
#    is_not_duplicate_entry):
# --------------------
# if (user_active and
# user_has_permissions):
# --------------------
# if (validate_input(data) and
#      ensure_data_security(data)):
# --------------------
# if (data_is_ready and
# 		process_data_now()):
# --------------------
# if (can_proceed() and
#      is_safe_operation()):
# --------------------
# if (model_is_trained and
# 			  generate_predictions()):
# --------------------
# if (send_data_available and
# 	send_data()):
# --------------------
# if (data_clean and
# 		        pass_checks()):
# --------------------
# if (user_authenticated and
# 			user_not_restricted()):
# --------------------
# Mark the sample as processed? y/n:
#  y
# Sample #5: Add some extra indentation on the conditional continuation line.
#
# PROMPT:
#
# You are an expert programmer with extensive experience and vast knowledge of different industries. You will help me create a dataset for correcting a code style according to the PEP 8 Python guideline.
#
# You will be given an example of a stylistically *wrong* snippet, and your task is to generate a total of 10 similar snippets. When generating snippets, you must strictly adhere to the following instructions:
#
# <instructions>
# 1. Snippets are valid pieces of Python code that must be similar to the provided <wrong_snippet> example in a sense that they *must violate* a certain <style_rule> (all relevant data are provided to you below in the corresponding XML sections).
# 2. When generating similar wrong snippets, you may and should change the <wrong_snippet> example in all possible ways, except for one rule:
# 3. Snippets must not be identical to the <correct_snippet> in the <style_rule>
# 4. Since you will generate snippets for a ML dataset, they must have some variability, being different both from the provided examples and from each other. To provide this variability, you need to modify the provided examples in the aspects from the <other_aspects> data section. If some aspects from <other_aspects> are irrelevant to the provided examples, you can safely ignore them, and focus on relevant ones instead.
# 5. Pay special attention to identation: some <style_rule>s rely on a specific, fixed number of spaces in each new line of code (starting from '\n' symbol), so pay close attention *not* to keep the identation identical to the one provided in the <correct_snippet> example.
# </instructions>
#
# <style_rule>
# Add some extra indentation on the conditional continuation line.
# </style_rule>
#
# <correct_snippet>
# if (this_is_one_thing
#         and that_is_another_thing):
# </correct_snippet>
#
# <wrong_snippet>
# if (this_is_one_thing
#      and that_is_another_thing):
# </wrong_snippet>
#
# <other_aspects>
# - variable naming
# - function naming
#
# </other_aspects>
#
# <output_instruction>
# 1. By comparing the <correct_snippet> and <wrong_snippet>, start your output with defining all possible ways in which you can violate the <style rule>. Use all your experience of code reviewing to list out all the cases, in which inexperienced programmers could violate the rule, and enclose these cases into the <violate_instructions> tags.
# 2. Paying close attention in order *not* to generate the correct sample as in in the <correct_snippet> example, and using <violate_instructions> you just wrote, start generating stylistically wrong snippets that violate the <style_rule>. Each case from the <violate_instructions> should be covered by at least one generated snipper.
# 3. Generated snippets should be in the following format:
#     <result>
#     {code_snippet_1}
#     --
#     {code_snippet_2}
#     --
#     ...
#     --
#     {code_snippet_10}
#     </result>
# </output_instruction>
#
# RESPONSE:
# <violate_instructions>
# - Use similar indentation as the first line for the continuation part.
# - Add insufficient extra indentation to the continuation line, making it visually align under a wrong part of the conditional statement.
# - Randomly increase or decrease spaces for the continuation line that does not match with any specific syntax elements of the first line.
# </violate_instructions>
#
# <result>
# if (check_this_value
#      and compare_with_that):
# --
# if (item_is_available
#      and quantity_is_sufficient):
# --
# if (user_is_active
#      and account_is_verified):
# --
# if (x < y
#      and x > 0):
# --
# if (valid_response
#      and contains_required_data):
# --
# if (received_signal
#      and is_within_range):
# --
# if (window_is_open
#      and door_is_locked):
# --
# if (has_all_permissions
#      and not is_restricted):
# --
# if (variable_one
#      and variable_two):
# --
# if (data_is_loaded
#      and data_is_valid):
# </result>
# if (check_this_value
#      and compare_with_that):
# --------------------
# if (item_is_available
#      and quantity_is_sufficient):
# --------------------
# if (user_is_active
#      and account_is_verified):
# --------------------
# if (x < y
#      and x > 0):
# --------------------
# if (valid_response
#      and contains_required_data):
# --------------------
# if (received_signal
#      and is_within_range):
# --------------------
# if (window_is_open
#      and door_is_locked):
# --------------------
# if (has_all_permissions
#      and not is_restricted):
# --------------------
# if (variable_one
#      and variable_two):
# --------------------
# if (data_is_loaded
#      and data_is_valid):
# --------------------
# Mark the sample as processed? y/n:
#  n
# Sample #6: The closing brace/bracket/parenthesis on multiline constructs must be lined up under the first character of the line that starts the multiline construct (collection case)
#
# PROMPT:
#
# You are an expert programmer with extensive experience and vast knowledge of different industries. You will help me create a dataset for correcting a code style according to the PEP 8 Python guideline.
#
# You will be given an example of a stylistically *wrong* snippet, and your task is to generate a total of 10 similar snippets. When generating snippets, you must strictly adhere to the following instructions:
#
# <instructions>
# 1. Snippets are valid pieces of Python code that must be similar to the provided <wrong_snippet> example in a sense that they *must violate* a certain <style_rule> (all relevant data are provided to you below in the corresponding XML sections).
# 2. When generating similar wrong snippets, you may and should change the <wrong_snippet> example in all possible ways, except for one rule:
# 3. Snippets must not be identical to the <correct_snippet> in the <style_rule>
# 4. Since you will generate snippets for a ML dataset, they must have some variability, being different both from the provided examples and from each other. To provide this variability, you need to modify the provided examples in the aspects from the <other_aspects> data section. If some aspects from <other_aspects> are irrelevant to the provided examples, you can safely ignore them, and focus on relevant ones instead.
# 5. Pay special attention to identation: some <style_rule>s rely on a specific, fixed number of spaces in each new line of code (starting from '\n' symbol), so pay close attention *not* to keep the identation identical to the one provided in the <correct_snippet> example.
# </instructions>
#
# <style_rule>
# The closing brace/bracket/parenthesis on multiline constructs must be lined up under the first character of the line that starts the multiline construct (collection case)
# </style_rule>
#
# <correct_snippet>
# my_list = [
#     1, 2, 3,
#     4, 5, 6,
# ]
# </correct_snippet>
#
# <wrong_snippet>
# my_list = [
#     1, 2, 3,
#   4, 5, 6,
# ]
# </wrong_snippet>
#
# <other_aspects>
# - variable naming
# - function naming
# - type of a collection data structure used (list/tuple/dictionary)
#
# </other_aspects>
#
# <output_instruction>
# 1. By comparing the <correct_snippet> and <wrong_snippet>, start your output with defining all possible ways in which you can violate the <style rule>. Use all your experience of code reviewing to list out all the cases, in which inexperienced programmers could violate the rule, and enclose these cases into the <violate_instructions> tags.
# 2. Paying close attention in order *not* to generate the correct sample as in in the <correct_snippet> example, and using <violate_instructions> you just wrote, start generating stylistically wrong snippets that violate the <style_rule>. Each case from the <violate_instructions> should be covered by at least one generated snipper.
# 3. Generated snippets should be in the following format:
#     <result>
#     {code_snippet_1}
#     --
#     {code_snippet_2}
#     --
#     ...
#     --
#     {code_snippet_10}
#     </result>
# </output_instruction>
#
# RESPONSE:
# <violate_instructions>
# - The closing bracket may be indented with fewer spaces than the line that starts the multiline construct.
# - The closing bracket may be indented with more spaces than the line that starts the multiline construct.
# - The closing bracket can be on the same line with the last item in the collection.
# - The closing bracket can be mixed with non-uniform indentation of the collection items.
# </violate_instructions>
#
# <result>
# # Example 1: Less indentation than start
# config_settings = {
#     'setting1': True,
#     'setting2': False,
#   }
#
# --
# # Example 2: More indentation than start
# user_ids = [
#     101, 102, 103,
#     104, 105, 106,
#         ]
#
# --
# # Example 3: Closing bracket on the same line as last item
# fruit_basket = [
#     'apple', 'banana', 'cherry',
#     'date', 'elderberry', 'fig']
#
# --
# # Example 4: Non-uniform item indentation with closing bracket indented less
# scores = {
#   'Alice': 88, 'Bob': 92,
#     'Charlie': 85,
#   }
#
# --
# # Example 5: Non-uniform item indentation with closing bracket indented more
# process_data = (
#     300, 450,
#   675,
#         )
#
# --
# # Example 6: Closing bracket well below the original line level
# employee_info = {
#     'Name': 'John',
#     'Age': 30,
#     'Department': 'HR',
#         }
#
# --
# # Example 7: No extra indentation on closing bracket
# names_list = [
#     'Sarah', 'Lora',
#     'Michael', 'Tom',
# ]
#
# --
# # Example 8: Excessive indentation before closing brace
# event_days = {
#     'Monday': ['Lecture', 'Seminar'],
#     'Tuesday': ['Workshop'],
#         }
#
# --
# # Example 9: Closing bracket on the next line, but too far indented
# object_types = (
#     int, float, str,
#     dict, list, tuple,
#                 )
#
# --
# # Example 10: Mixed indentation levels, inconsistent with starting line
# parameter_ranges = {
#     'param1': [1, 20],
#   'param2': [30, 60],
#     'param3': [70, 100],
#   }
# </result>
# # Example 1: Less indentation than start
# config_settings = {
#     'setting1': True,
#     'setting2': False,
#   }
# --------------------
# # Example 2: More indentation than start
# user_ids = [
#     101, 102, 103,
#     104, 105, 106,
#         ]
# --------------------
# # Example 3: Closing bracket on the same line as last item
# fruit_basket = [
#     'apple', 'banana', 'cherry',
#     'date', 'elderberry', 'fig']
# --------------------
# # Example 4: Non-uniform item indentation with closing bracket indented less
# scores = {
#   'Alice': 88, 'Bob': 92,
#     'Charlie': 85,
#   }
# --------------------
# # Example 5: Non-uniform item indentation with closing bracket indented more
# process_data = (
#     300, 450,
#   675,
#         )
# --------------------
# # Example 6: Closing bracket well below the original line level
# employee_info = {
#     'Name': 'John',
#     'Age': 30,
#     'Department': 'HR',
#         }
# --------------------
# # Example 7: No extra indentation on closing bracket
# names_list = [
#     'Sarah', 'Lora',
#     'Michael', 'Tom',
# ]
# --------------------
# # Example 8: Excessive indentation before closing brace
# event_days = {
#     'Monday': ['Lecture', 'Seminar'],
#     'Tuesday': ['Workshop'],
#         }
# --------------------
# # Example 9: Closing bracket on the next line, but too far indented
# object_types = (
#     int, float, str,
#     dict, list, tuple,
#                 )
# --------------------
# # Example 10: Mixed indentation levels, inconsistent with starting line
# parameter_ranges = {
#     'param1': [1, 20],
#   'param2': [30, 60],
#     'param3': [70, 100],
#   }
# --------------------
# Mark the sample as processed? y/n:
#  n
# Sample #7: The closing brace/bracket/parenthesis on multiline constructs must be lined up under the first character of the line that starts the multiline construct (function call case)
#
# PROMPT:
#
# You are an expert programmer with extensive experience and vast knowledge of different industries. You will help me create a dataset for correcting a code style according to the PEP 8 Python guideline.
#
# You will be given an example of a stylistically *wrong* snippet, and your task is to generate a total of 10 similar snippets. When generating snippets, you must strictly adhere to the following instructions:
#
# <instructions>
# 1. Snippets are valid pieces of Python code that must be similar to the provided <wrong_snippet> example in a sense that they *must violate* a certain <style_rule> (all relevant data are provided to you below in the corresponding XML sections).
# 2. When generating similar wrong snippets, you may and should change the <wrong_snippet> example in all possible ways, except for one rule:
# 3. Snippets must not be identical to the <correct_snippet> in the <style_rule>
# 4. Since you will generate snippets for a ML dataset, they must have some variability, being different both from the provided examples and from each other. To provide this variability, you need to modify the provided examples in the aspects from the <other_aspects> data section. If some aspects from <other_aspects> are irrelevant to the provided examples, you can safely ignore them, and focus on relevant ones instead.
# 5. Pay special attention to identation: some <style_rule>s rely on a specific, fixed number of spaces in each new line of code (starting from '\n' symbol), so pay close attention *not* to keep the identation identical to the one provided in the <correct_snippet> example.
# </instructions>
#
# <style_rule>
# The closing brace/bracket/parenthesis on multiline constructs must be lined up under the first character of the line that starts the multiline construct (function call case)
# </style_rule>
#
# <correct_snippet>
# result = some_function_that_takes_arguments(
#     'a', 'b', 'c',
#     'd', 'e', 'f',
# )
# </correct_snippet>
#
# <wrong_snippet>
# result = some_function_that_takes_arguments(
#     'a', 'b', 'c',
#       'd', 'e', 'f',
# )
# </wrong_snippet>
#
# <other_aspects>
# - variable naming
# - function naming
# - number of function arguments
# - names of function arguments
# - length of function arguments (all arguments must be of different length)
#
# </other_aspects>
#
# <output_instruction>
# 1. By comparing the <correct_snippet> and <wrong_snippet>, start your output with defining all possible ways in which you can violate the <style rule>. Use all your experience of code reviewing to list out all the cases, in which inexperienced programmers could violate the rule, and enclose these cases into the <violate_instructions> tags.
# 2. Paying close attention in order *not* to generate the correct sample as in in the <correct_snippet> example, and using <violate_instructions> you just wrote, start generating stylistically wrong snippets that violate the <style_rule>. Each case from the <violate_instructions> should be covered by at least one generated snipper.
# 3. Generated snippets should be in the following format:
#     <result>
#     {code_snippet_1}
#     --
#     {code_snippet_2}
#     --
#     ...
#     --
#     {code_snippet_10}
#     </result>
# </output_instruction>
#
# RESPONSE:
# <violate_instructions>
# - The closing parenthesis should not be lined up under the first character of the line that starts the multiline construct but should be on a different column.
# - The closing parenthesis can be indented too much or not enough, relative to the start of the function call.
# - We can have the closing parenthesis aligned more to the left or right than the function's starting alignment, making it either under-indented or over-indented compared to the line starting the multiline construct.
# </violate_instructions>
#
# <result>
# calculation = calculate_total_sum(
#     123, 456, 789,
#      101112, 131415, 161718,
#     )
# --
# output = fetch_data_records(
#     "alpha", "beta", "gamma",
#    "delta", "epsilon", "zeta",
#     )
# --
# response = process_user_input(
#     "username", "password", "email",
#       "dob", "city", "country",
#     )
# --
# final_score = compute_scores(
#     "math", "science", "literature",
#             "history", "geography", "arts",
#     )
# --
# transformed_data = transform_data_set(
#     "input", "output", "temp",
#   "intermediate", "final", "result",
#     )
# --
# metadata = extract_metadata_from(
#     'title', 'author', 'publisher',
#     'year', 'ISBN', 'genre',
#       )
# --
# connection_details = get_connection_params(
#     "host", "port", "database",
#   "user", "password", "options",
#     )
# --
# content = load_website_content(
#     "url", "timeout", "user_agent",
#   "headers", "cookies", "proxy",
#     )
# --
# record = create_db_record(
#     "first_name", "last_name", "email",
#      "age", "occupation", "nationality",
#     )
# --
# result = query_database(
#     'table', 'columns', 'conditions',
#       'group_by', 'order_by', 'limit',
#     )
# </result>
# calculation = calculate_total_sum(
#     123, 456, 789,
#      101112, 131415, 161718,
#     )
# --------------------
# output = fetch_data_records(
#     "alpha", "beta", "gamma",
#    "delta", "epsilon", "zeta",
#     )
# --------------------
# response = process_user_input(
#     "username", "password", "email",
#       "dob", "city", "country",
#     )
# --------------------
# final_score = compute_scores(
#     "math", "science", "literature",
#             "history", "geography", "arts",
#     )
# --------------------
# transformed_data = transform_data_set(
#     "input", "output", "temp",
#   "intermediate", "final", "result",
#     )
# --------------------
# metadata = extract_metadata_from(
#     'title', 'author', 'publisher',
#     'year', 'ISBN', 'genre',
#       )
# --------------------
# connection_details = get_connection_params(
#     "host", "port", "database",
#   "user", "password", "options",
#     )
# --------------------
# content = load_website_content(
#     "url", "timeout", "user_agent",
#   "headers", "cookies", "proxy",
#     )
# --------------------
# record = create_db_record(
#     "first_name", "last_name", "email",
#      "age", "occupation", "nationality",
#     )
# --------------------
# result = query_database(
#     'table', 'columns', 'conditions',
#       'group_by', 'order_by', 'limit',
#     )
# --------------------
# Mark the sample as processed? y/n:
#  y

# %%
df_wrong.to_csv(fname_wrong, mode='w', index=True, quoting=csv.QUOTE_ALL)
